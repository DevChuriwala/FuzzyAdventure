# %%
# !nvidia-smi
# Out:
# Sat Aug  8 18:54:57 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    36W / 250W |    903MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time

# %%
class LeNet(nn.Module):
  
  def __init__(self, classes):
    super(LeNet, self).__init__()

    self.extract = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=20, kernel_size=5, stride=1), #LeNet-5 used 6 filters, I've used 20 filters
        nn.BatchNorm2d(20),
        nn.ReLU(),
        nn.AvgPool2d(kernel_size=2, stride=2),
        nn.Dropout(p = 0.2),
        nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1), #LeNet-5 used 16 filters, I've used 50 filters
        nn.BatchNorm2d(50),
        nn.ReLU(),
        nn.AvgPool2d(kernel_size=2, stride=2),
        nn.Dropout(p = 0.2),        
    )

    self.classify = nn.Sequential(
        nn.Linear(in_features=1250, out_features=500), #I've used 500 FC channels instead of 120, expect CIFAR to contain more distinct features than MNIST
        nn.BatchNorm1d(500),
        nn.ReLU(),
        nn.Linear(in_features=500, out_features=classes)
    )

  def forward(self, x):
    x = self.extract(x)
    x = torch.flatten(x, 1)
    logits = self.classify(x)
    return logits

# %%
train_transform = transforms.Compose([ transforms.RandomCrop(32, padding=4),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.4247, 0.4150, 0.3840], [0.2827, 0.2777, 0.2844])]) #Calculated using https://github.com/Armour/pytorch-nn-practice/blob/master/utils/meanstd.py
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize([0.4942, 0.4851, 0.4504], [0.2467, 0.2429, 0.2616])]) 

trainset = torchvision.datasets.CIFAR10(root='/content/data', train=True, download=True, transform=train_transform)
testset = torchvision.datasets.CIFAR10(root='/content/data', train=False, download=True, transform=test_transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=16)
testloader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=True, num_workers=16)

dataset_sizes = {'train':len(trainset), 'val':len(testset)}
dataloaders = {'train':trainloader, 'val':testloader}

class_names = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def online_mean_and_sd(loader):

  """Compute the mean and sd in an online fashion

        Var[x] = E[X^2] - E^2[X]
    """
  cnt = 0
  fst_moment = torch.empty(3)
  snd_moment = torch.empty(3)

  for images, _ in loader:

      b, c, h, w = images.shape
      nb_pixels = b * h * w
      sum_ = torch.sum(images, dim=[0, 2, 3])
      sum_of_square = torch.sum(images ** 2, dim=[0, 2, 3])
      fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
      snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)

      cnt += nb_pixels

  return fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)

food101_mean, food101_std = online_mean_and_sd(dataloaders["train"])
print(food101_mean, food101_std)
# Out:
# tensor([-0.0006, -0.0007, -0.0007]) tensor([1.0002, 1.0003, 0.9999])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):

    for epoch in range(num_epochs):
        since = time.time()
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and test phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to test mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            time_elapsed = time.time() - since
            print('Training complete in {:.0f}m {:.0f}s'.format(
            time_elapsed // 60, time_elapsed % 60))            
            
            torch.save(model.state_dict(), '/content/CIFAR10_LeNet_Epoch_' + str(epoch+1) + '.pth')

        print()
    return model

# %%
model = LeNet(10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.15, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %%
prev_state = torch.load('/content/CIFAR10_LeNet_Epoch_35.pth')
model.load_state_dict(prev_state)

# %%
model = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.7390 Acc: 0.3816
# Training complete in 0m 7s
# val Loss: 1.4100 Acc: 0.4894
# Training complete in 0m 9s
#
# Epoch 2/50
# ----------
# train Loss: 1.4184 Acc: 0.4870
# Training complete in 0m 7s
# val Loss: 1.2388 Acc: 0.5546
# Training complete in 0m 9s
#
# Epoch 3/50
# ----------
# train Loss: 1.2859 Acc: 0.5368
# Training complete in 0m 7s
# val Loss: 1.1484 Acc: 0.5896
# Training complete in 0m 9s
#
# Epoch 4/50
# ----------
# train Loss: 1.1920 Acc: 0.5766
# Training complete in 0m 7s
# val Loss: 1.0809 Acc: 0.6142
# Training complete in 0m 9s
#
# Epoch 5/50
# ----------
# train Loss: 1.1252 Acc: 0.5993
# Training complete in 0m 7s
# val Loss: 1.0422 Acc: 0.6352
# Training complete in 0m 9s
#
# Epoch 6/50
# ----------
# train Loss: 1.0672 Acc: 0.6204
# Training complete in 0m 7s
# val Loss: 0.9991 Acc: 0.6549
# Training complete in 0m 9s
#
# Epoch 7/50
# ----------
# train Loss: 1.0249 Acc: 0.6373
# Training complete in 0m 7s
# val Loss: 1.0033 Acc: 0.6536
# Training complete in 0m 9s
#
# Epoch 8/50
# ----------
# train Loss: 0.9931 Acc: 0.6512
# Training complete in 0m 7s
# val Loss: 0.9148 Acc: 0.6830
# Training complete in 0m 9s
#
# Epoch 9/50
# ----------
# train Loss: 0.9607 Acc: 0.6618
# Training complete in 0m 7s
# val Loss: 0.8534 Acc: 0.7034
# Training complete in 0m 9s
#
# Epoch 10/50
# ----------
# train Loss: 0.9414 Acc: 0.6664
# Training complete in 0m 7s
# val Loss: 0.8398 Acc: 0.7075
# Training complete in 0m 9s
#
# Epoch 11/50
# ----------
# train Loss: 0.8527 Acc: 0.6984
# Training complete in 0m 7s
# val Loss: 0.7578 Acc: 0.7369
# Training complete in 0m 9s
#
# Epoch 12/50
# ----------
# train Loss: 0.8165 Acc: 0.7120
# Training complete in 0m 7s
# val Loss: 0.7474 Acc: 0.7393
# Training complete in 0m 9s
#
# Epoch 13/50
# ----------
# train Loss: 0.8113 Acc: 0.7124
# Training complete in 0m 7s
# val Loss: 0.7464 Acc: 0.7426
# Training complete in 0m 9s
#
# Epoch 14/50
# ----------
# train Loss: 0.7980 Acc: 0.7180
# Training complete in 0m 7s
# val Loss: 0.7382 Acc: 0.7422
# Training complete in 0m 9s
#
# Epoch 15/50
# ----------
# train Loss: 0.7933 Acc: 0.7222
# Training complete in 0m 7s
# val Loss: 0.7302 Acc: 0.7447
# Training complete in 0m 9s
#
# Epoch 16/50
# ----------
# train Loss: 0.7891 Acc: 0.7235
# Training complete in 0m 8s
# val Loss: 0.7426 Acc: 0.7399
# Training complete in 0m 9s
#
# Epoch 17/50
# ----------
# train Loss: 0.7820 Acc: 0.7232
# Training complete in 0m 7s
# val Loss: 0.7267 Acc: 0.7439
# Training complete in 0m 9s
#
# Epoch 18/50
# ----------
# train Loss: 0.7754 Acc: 0.7287
# Training complete in 0m 7s
# val Loss: 0.7121 Acc: 0.7477
# Training complete in 0m 9s
#
# Epoch 19/50
# ----------
# train Loss: 0.7727 Acc: 0.7283
# Training complete in 0m 7s
# val Loss: 0.7030 Acc: 0.7544
# Training complete in 0m 9s
#
# Epoch 20/50
# ----------
# train Loss: 0.7650 Acc: 0.7292
# Training complete in 0m 7s
# val Loss: 0.6996 Acc: 0.7533
# Training complete in 0m 9s
#
# Epoch 21/50
# ----------
# train Loss: 0.7613 Acc: 0.7317
# Training complete in 0m 7s
# val Loss: 0.6972 Acc: 0.7559
# Training complete in 0m 9s
#
# Epoch 22/50
# ----------
# train Loss: 0.7554 Acc: 0.7324
# Training complete in 0m 7s
# val Loss: 0.7056 Acc: 0.7535
# Training complete in 0m 9s
#
# Epoch 23/50
# ----------
# train Loss: 0.7538 Acc: 0.7346
# Training complete in 0m 7s
# val Loss: 0.7022 Acc: 0.7537
# Training complete in 0m 9s
#
# Epoch 24/50
# ----------
# train Loss: 0.7511 Acc: 0.7358
# Training complete in 0m 7s
# val Loss: 0.7070 Acc: 0.7526
# Training complete in 0m 9s
#
# Epoch 25/50
# ----------
# train Loss: 0.7498 Acc: 0.7355
# Training complete in 0m 7s
# val Loss: 0.7018 Acc: 0.7521
# Training complete in 0m 9s
#
# Epoch 26/50
# ----------
# train Loss: 0.7546 Acc: 0.7368
# Training complete in 0m 7s
# val Loss: 0.7040 Acc: 0.7535
# Training complete in 0m 9s
#
# Epoch 27/50
# ----------
# train Loss: 0.7513 Acc: 0.7341
# Training complete in 0m 7s
# val Loss: 0.7059 Acc: 0.7527
# Training complete in 0m 9s
#
# Epoch 28/50
# ----------
# train Loss: 0.7515 Acc: 0.7354
# Training complete in 0m 7s
# val Loss: 0.6967 Acc: 0.7561
# Training complete in 0m 9s
#
# Epoch 29/50
# ----------
# train Loss: 0.7502 Acc: 0.7370
# Training complete in 0m 7s
# val Loss: 0.6970 Acc: 0.7545
# Training complete in 0m 9s
#
# Epoch 30/50
# ----------
# train Loss: 0.7499 Acc: 0.7375
# Training complete in 0m 7s
# val Loss: 0.7043 Acc: 0.7533
# Training complete in 0m 9s
#
# Epoch 31/50
# ----------
# train Loss: 0.7463 Acc: 0.7366
# Training complete in 0m 7s
# val Loss: 0.7001 Acc: 0.7546
# Training complete in 0m 9s
#
# Epoch 32/50
# ----------
# train Loss: 0.7513 Acc: 0.7354
# Training complete in 0m 7s
# val Loss: 0.7035 Acc: 0.7532
# Training complete in 0m 9s
#
# Epoch 33/50
# ----------
# train Loss: 0.7466 Acc: 0.7385
# Training complete in 0m 7s
# val Loss: 0.6955 Acc: 0.7568
# Training complete in 0m 9s
#
# Epoch 34/50
# ----------
# train Loss: 0.7519 Acc: 0.7340
# Training complete in 0m 7s
# val Loss: 0.7045 Acc: 0.7531
# Training complete in 0m 9s
#
# Epoch 35/50
# ----------
# train Loss: 0.7448 Acc: 0.7371
# Training complete in 0m 7s
# val Loss: 0.6981 Acc: 0.7549
# Training complete in 0m 9s
#
# Epoch 36/50
# ----------
# train Loss: 0.7460 Acc: 0.7369
# Training complete in 0m 7s
# val Loss: 0.6941 Acc: 0.7574
# Training complete in 0m 9s
#
# Epoch 37/50
# ----------
# train Loss: 0.7465 Acc: 0.7369
# Training complete in 0m 7s
# val Loss: 0.7025 Acc: 0.7554
# Training complete in 0m 9s
#
# Epoch 38/50
# ----------
# train Loss: 0.7511 Acc: 0.7359
# Training complete in 0m 7s
# val Loss: 0.7083 Acc: 0.7523
# Training complete in 0m 9s
#
# Epoch 39/50
# ----------
# train Loss: 0.7498 Acc: 0.7351
# Training complete in 0m 7s
# val Loss: 0.6994 Acc: 0.7556
# Training complete in 0m 9s
#
# Epoch 40/50
# ----------
# train Loss: 0.7482 Acc: 0.7355
# Training complete in 0m 7s
# val Loss: 0.7004 Acc: 0.7554
# Training complete in 0m 9s
#
# Epoch 41/50
# ----------
# train Loss: 0.7467 Acc: 0.7368
# Training complete in 0m 7s
# val Loss: 0.6996 Acc: 0.7543
# Training complete in 0m 9s
#
# Epoch 42/50
# ----------
# train Loss: 0.7446 Acc: 0.7369
# Training complete in 0m 7s
# val Loss: 0.7076 Acc: 0.7530
# Training complete in 0m 9s
#
# Epoch 43/50
# ----------
# train Loss: 0.7470 Acc: 0.7368
# Training complete in 0m 7s
# val Loss: 0.7068 Acc: 0.7528
# Training complete in 0m 9s
#
# Epoch 44/50
# ----------
# train Loss: 0.7440 Acc: 0.7378
# Training complete in 0m 7s
# val Loss: 0.7011 Acc: 0.7529
# Training complete in 0m 9s
#
# Epoch 45/50
# ----------
# train Loss: 0.7450 Acc: 0.7365
# Training complete in 0m 7s
# val Loss: 0.6975 Acc: 0.7550
# Training complete in 0m 9s
#
# Epoch 46/50
# ----------
# train Loss: 0.7467 Acc: 0.7379
# Training complete in 0m 7s
# val Loss: 0.7040 Acc: 0.7543
# Training complete in 0m 9s
#
# Epoch 47/50
# ----------
# train Loss: 0.7429 Acc: 0.7396
# Training complete in 0m 7s
# val Loss: 0.7016 Acc: 0.7557
# Training complete in 0m 9s
#
# Epoch 48/50
# ----------
# train Loss: 0.7434 Acc: 0.7362
# Training complete in 0m 7s
# val Loss: 0.6992 Acc: 0.7549
# Training complete in 0m 9s
#
# Epoch 49/50
# ----------
# train Loss: 0.7450 Acc: 0.7364
# Training complete in 0m 7s
# val Loss: 0.7008 Acc: 0.7542
# Training complete in 0m 9s
#
# Epoch 50/50
# ----------
# train Loss: 0.7491 Acc: 0.7376
# Training complete in 0m 7s
# val Loss: 0.7054 Acc: 0.7544
# Training complete in 0m 9s
